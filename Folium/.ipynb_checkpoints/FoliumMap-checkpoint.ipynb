# %%
import folium

# Definindo as coordenadas de Porto Alegre
latitude = -30.0346
longitude = -51.2177

# Criando um mapa centrado em Porto Alegre
mapa = folium.Map(location=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para Porto Alegre 
folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b9ed12826ca35e7ed9b9e825d017136 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b9ed12826ca35e7ed9b9e825d017136&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b9ed12826ca35e7ed9b9e825d017136 = L.map(
#                 &quot;map_4b9ed12826ca35e7ed9b9e825d017136&quot;,
#                 {
#                     center: [-30.0346, -51.2177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f51f2657b139545e3154fe8b078057b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f51f2657b139545e3154fe8b078057b1.addTo(map_4b9ed12826ca35e7ed9b9e825d017136);
#
#
#             var marker_50b1c65d7aec3d42507812675c963026 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_4b9ed12826ca35e7ed9b9e825d017136);
#
#
#         var popup_f4f58f38bb2fa18673c9fd4218f73a88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be4a3a79552b897d40f8d5a9eceb57cd = $(`&lt;div id=&quot;html_be4a3a79552b897d40f8d5a9eceb57cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_f4f58f38bb2fa18673c9fd4218f73a88.setContent(html_be4a3a79552b897d40f8d5a9eceb57cd);
#
#
#
#         marker_50b1c65d7aec3d42507812675c963026.bindPopup(popup_f4f58f38bb2fa18673c9fd4218f73a88)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Definindo as coordenadas de São Paulo
latitude = -23.5505
longitude = -46.6333

# Criando um mapa centrado em São Paulo
mapa = folium.Map(location=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para São Paulo
folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18a8cd0a821dc92fcfe2c28a20ef9b42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18a8cd0a821dc92fcfe2c28a20ef9b42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18a8cd0a821dc92fcfe2c28a20ef9b42 = L.map(
#                 &quot;map_18a8cd0a821dc92fcfe2c28a20ef9b42&quot;,
#                 {
#                     center: [-23.5505, -46.6333],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a29e6eb015527ba70ecc66616e72b6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5a29e6eb015527ba70ecc66616e72b6a.addTo(map_18a8cd0a821dc92fcfe2c28a20ef9b42);
#
#
#             var marker_945f90244b72691f960f0b18757f5867 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_18a8cd0a821dc92fcfe2c28a20ef9b42);
#
#
#         var popup_bf7a1b59c32e49a175a6ee60f379a8f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb8020be4d22231537ab8f142d315dc7 = $(`&lt;div id=&quot;html_cb8020be4d22231537ab8f142d315dc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_bf7a1b59c32e49a175a6ee60f379a8f1.setContent(html_cb8020be4d22231537ab8f142d315dc7);
#
#
#
#         marker_945f90244b72691f960f0b18757f5867.bindPopup(popup_bf7a1b59c32e49a175a6ee60f379a8f1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Definindo as coordenadas de Rio de Janeiro
latitude = -22.9068
longitude = -43.1729

# Criando um mapa centrado em Rio de Janeiro
mapa = folium.Map(location=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para Rio de Janeiro
folium.Marker([latitude, longitude], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2aa04c55164a64d3388e1d429bdda66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2aa04c55164a64d3388e1d429bdda66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2aa04c55164a64d3388e1d429bdda66 = L.map(
#                 &quot;map_c2aa04c55164a64d3388e1d429bdda66&quot;,
#                 {
#                     center: [-22.9068, -43.1729],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae2615693838278625ae6a84383e62b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ae2615693838278625ae6a84383e62b1.addTo(map_c2aa04c55164a64d3388e1d429bdda66);
#
#
#             var marker_c6e2c8ee9857ba36eece1b933888c616 = L.marker(
#                 [-22.9068, -43.1729],
#                 {}
#             ).addTo(map_c2aa04c55164a64d3388e1d429bdda66);
#
#
#         var popup_f6c96f13f25ced8757fcea8970a94c84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36fcdd0467958ceb58ee6e997f7d7b67 = $(`&lt;div id=&quot;html_36fcdd0467958ceb58ee6e997f7d7b67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_f6c96f13f25ced8757fcea8970a94c84.setContent(html_36fcdd0467958ceb58ee6e997f7d7b67);
#
#
#
#         marker_c6e2c8ee9857ba36eece1b933888c616.bindPopup(popup_f6c96f13f25ced8757fcea8970a94c84)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Definindo as coordenadas de Curitiba
latitude = -25.4290
longitude = -49.2671

# Criando um mapa centrado em Curitiba
mapa = folium.Map(location=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para Curitiba 
folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c94f4d196c2cda4c9db23a8d651713ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c94f4d196c2cda4c9db23a8d651713ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c94f4d196c2cda4c9db23a8d651713ba = L.map(
#                 &quot;map_c94f4d196c2cda4c9db23a8d651713ba&quot;,
#                 {
#                     center: [-25.429, -49.2671],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd017ea4f736bf88c2e2924b5124ee1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd017ea4f736bf88c2e2924b5124ee1c.addTo(map_c94f4d196c2cda4c9db23a8d651713ba);
#
#
#             var marker_78444298df8ce8564c16507a14ef2235 = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_c94f4d196c2cda4c9db23a8d651713ba);
#
#
#         var popup_9a0115852ebbc437ed511052967022d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1225c911a25f4ee1f86c010f333bc0d8 = $(`&lt;div id=&quot;html_1225c911a25f4ee1f86c010f333bc0d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_9a0115852ebbc437ed511052967022d7.setContent(html_1225c911a25f4ee1f86c010f333bc0d8);
#
#
#
#         marker_78444298df8ce8564c16507a14ef2235.bindPopup(popup_9a0115852ebbc437ed511052967022d7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Definindo as coordenadas de Belo Horizonte
latitude = -19.9173
longitude = -43.9345

# Criando um mapa centrado em Belo Horizonte
mapa = folium.Map(location=[latitude, longitude], zoom_start=12)

# Adicionando um marcador para Belo Horizonte
folium.Marker([latitude, longitude], popup='Belo Horizonte, MG, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c23a9de70083c0d377b7274bdf3e4723 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c23a9de70083c0d377b7274bdf3e4723&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c23a9de70083c0d377b7274bdf3e4723 = L.map(
#                 &quot;map_c23a9de70083c0d377b7274bdf3e4723&quot;,
#                 {
#                     center: [-19.9173, -43.9345],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fdd2aad12c29cfbb3904cda5f53eea3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0fdd2aad12c29cfbb3904cda5f53eea3.addTo(map_c23a9de70083c0d377b7274bdf3e4723);
#
#
#             var marker_0f48bdf6cc60ad61c2ce9ccda364c037 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_c23a9de70083c0d377b7274bdf3e4723);
#
#
#         var popup_2c1d36786226e47f7fe1e803b7803c7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a67b49d5084188b9d35e501e1018435 = $(`&lt;div id=&quot;html_1a67b49d5084188b9d35e501e1018435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_2c1d36786226e47f7fe1e803b7803c7a.setContent(html_1a67b49d5084188b9d35e501e1018435);
#
#
#
#         marker_0f48bdf6cc60ad61c2ce9ccda364c037.bindPopup(popup_2c1d36786226e47f7fe1e803b7803c7a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Definindo as coordenas das capitais brasileiras:
# Mapa do Brasil (Região Sul)
latitude = -33.4507
longitude = -53.2350

# Criando um mapa centrado em Porto Alegre
mapa = folium.Map(location=[latitude, longitude], zoom_start=3)

# Porto Alegre
latitude = -30.0346
longitude = -51.2177

# Adicionando um marcador para Porto Alegre
folium.Marker([latitude, longitude], popup='Porto Alegre, RS, Brasil').add_to(mapa)

# Exibindo o mapa
mapa

# São Paulo
latitude = -23.5505
longitude = -46.6333

# Adicionando um marcador para São Paulo
folium.Marker([latitude, longitude], popup='São Paulo, SP, Brasil').add_to(mapa)

# Exibindo o mapa
mapa

# Rio de Janeiro
latitude = -22.9068
longitude = -42.1729

# Adicionando um marcador para Rio de Janeiro
folium.Marker([latitude, longitude], popup='Rio de Janeiro, RJ, Brasil').add_to(mapa)

# Exibindo o mapa
mapa

# Curitiba
latitude = -25.4290
longitude = -49.2671

# Adicionando um marcador para Curitiba
folium.Marker([latitude, longitude], popup='Curitiba, PR, Brasil').add_to(mapa)

# Exibindo o mapa
mapa

# Belo Horizonte
latitude = -19.9173
longitude = -43.9345

# Adicionando um marcador para Belo Horizonte
folium.Marker([latitude, longitude], popup='Belo Horizonte, MG, Brasil').add_to(mapa)

# Exibindo o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f60348d2011c695a162bb29d830ab31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f60348d2011c695a162bb29d830ab31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f60348d2011c695a162bb29d830ab31 = L.map(
#                 &quot;map_1f60348d2011c695a162bb29d830ab31&quot;,
#                 {
#                     center: [-33.4507, -53.235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_142417d4cae8a3a3bdfe23bace2673d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_142417d4cae8a3a3bdfe23bace2673d9.addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#             var marker_bf6b6c30198d9783304a7d41647b73c5 = L.marker(
#                 [-30.0346, -51.2177],
#                 {}
#             ).addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#         var popup_6441fc8dcbd59a0709e8924e29c4b145 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46805dbe164e65f11cf06fc783afdd87 = $(`&lt;div id=&quot;html_46805dbe164e65f11cf06fc783afdd87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Porto Alegre, RS, Brasil&lt;/div&gt;`)[0];
#                 popup_6441fc8dcbd59a0709e8924e29c4b145.setContent(html_46805dbe164e65f11cf06fc783afdd87);
#
#
#
#         marker_bf6b6c30198d9783304a7d41647b73c5.bindPopup(popup_6441fc8dcbd59a0709e8924e29c4b145)
#         ;
#
#
#
#
#             var marker_ef46012636c3048e066a75f577aa8973 = L.marker(
#                 [-23.5505, -46.6333],
#                 {}
#             ).addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#         var popup_6b9133863e90db6fb93a14550bbbbfe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f50a35d3a3ab829a5c29cfcee868191 = $(`&lt;div id=&quot;html_3f50a35d3a3ab829a5c29cfcee868191&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;São Paulo, SP, Brasil&lt;/div&gt;`)[0];
#                 popup_6b9133863e90db6fb93a14550bbbbfe3.setContent(html_3f50a35d3a3ab829a5c29cfcee868191);
#
#
#
#         marker_ef46012636c3048e066a75f577aa8973.bindPopup(popup_6b9133863e90db6fb93a14550bbbbfe3)
#         ;
#
#
#
#
#             var marker_b8e03f30fc94035a0f4abf1999c750d9 = L.marker(
#                 [-22.9068, -42.1729],
#                 {}
#             ).addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#         var popup_ee4257dd1cc155a07ac39aa0c25af707 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b1bedd4ce6598352ba14cad47c18690 = $(`&lt;div id=&quot;html_2b1bedd4ce6598352ba14cad47c18690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rio de Janeiro, RJ, Brasil&lt;/div&gt;`)[0];
#                 popup_ee4257dd1cc155a07ac39aa0c25af707.setContent(html_2b1bedd4ce6598352ba14cad47c18690);
#
#
#
#         marker_b8e03f30fc94035a0f4abf1999c750d9.bindPopup(popup_ee4257dd1cc155a07ac39aa0c25af707)
#         ;
#
#
#
#
#             var marker_6f61127f958d14c55a57c22c8b976ded = L.marker(
#                 [-25.429, -49.2671],
#                 {}
#             ).addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#         var popup_021eafa6baff6b8cd0fb7de493c84d60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bba05b0d32302e0c41cdca7f9957b34 = $(`&lt;div id=&quot;html_5bba05b0d32302e0c41cdca7f9957b34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba, PR, Brasil&lt;/div&gt;`)[0];
#                 popup_021eafa6baff6b8cd0fb7de493c84d60.setContent(html_5bba05b0d32302e0c41cdca7f9957b34);
#
#
#
#         marker_6f61127f958d14c55a57c22c8b976ded.bindPopup(popup_021eafa6baff6b8cd0fb7de493c84d60)
#         ;
#
#
#
#
#             var marker_b016bf3b081969b32d577390058f8c72 = L.marker(
#                 [-19.9173, -43.9345],
#                 {}
#             ).addTo(map_1f60348d2011c695a162bb29d830ab31);
#
#
#         var popup_fe3ea5fc256b4444cdb70fb87d5fb5f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15663f8b343c9f53e019e82b8dd6ed83 = $(`&lt;div id=&quot;html_15663f8b343c9f53e019e82b8dd6ed83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belo Horizonte, MG, Brasil&lt;/div&gt;`)[0];
#                 popup_fe3ea5fc256b4444cdb70fb87d5fb5f8.setContent(html_15663f8b343c9f53e019e82b8dd6ed83);
#
#
#
#         marker_b016bf3b081969b32d577390058f8c72.bindPopup(popup_fe3ea5fc256b4444cdb70fb87d5fb5f8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscree
